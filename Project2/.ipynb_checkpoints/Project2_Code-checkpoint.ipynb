# %%
import numpy as np
import time
import scipy
import random
from scipy import linalg as la
import math
import copy


#print(rho)

# %%
def find_max(array):
    m = 0
    p = 0
    q = 0
    dim = array.shape[0]
    for i in range(dim):

        for j in range(i+1,dim):

            if abs(array[i][j]) > abs(m) and i != j:
                m = abs(array[i][j])
                p = i
                q = j

    return m, p, q

def sct(a,p,q):
    tau = (a[q][q] - a[p][p])/(2*a[p][q])
    if tau < 0:
        tan = -1/(-tau+math.sqrt(1+tau**2))
    else:
        tan = 1/(tau+math.sqrt(1+tau**2))

    cos = 1/(math.sqrt(1+tan**2))
    sin = tan*cos
    
    return sin, cos

def transform(a,p,q,sin,cos):
    b = copy.copy(a)
    b[p][q] = 0
    b[q][p] = 0
    b[p][p] = a[p][p]*cos**2 - 2*a[p][q]*cos*sin + a[q][q]*sin**2
    b[q][q] = a[p][p]*sin**2 + 2*a[p][q]*cos*sin + a[q][q]*cos**2

    for i in range(a.ndim):
        if i != p and i != q:
            b[i][p] = cos*a[i][p] - sin*a[i][q]
            b[i][q] = cos*a[i][q] + sin*a[i][p]
            #b[i][i] = a[i][i]
            b[p][i] = b[i][p]
            b[q][i] = b[i][q]

    #print(b)
    return b

# %%
#a = np.array([[2,-4],[-4,1]])
#A = np.array(([4.,2.,0.],[2.,1.,2.],[0.,2.,4.]))
#print(A)

n = 100
rho_max = 5
rho_min = 0
rho = np.linspace(rho_min, rho_max, n)
omega = 1
l = 0
A = np.zeros((n-1,n-1))
h = (rho_max - rho_min)/n
main_diag = 2/(h**2)
sec_diag = -1/(h**2)



for i in range(0,n-1):
    rho_i = rho_min + (i+1)*h
    A[i][i] = main_diag + rho_i**2
    
for i in range(1,n-1):
    A[i][i-1] = A[i-1][i] = sec_diag
    
calc_eigvals = copy.copy(la.eigvals(A))
orig_matrix = copy.copy(A)

#print(A,calc_eigvals)

epsilon = 10**-10
max_e = 1
iters = 0
max_iters = n
while max_e > epsilon and iters < max_iters:

    max_e, p, q = find_max(A)
    #print(max_e,p,q,max_e > epsilon)
    if max_e < epsilon:
        break
    sin, cos = sct(A,p,q)
    A = transform(A,p,q,sin,cos)
    iters += 1

new_eigvals = la.eigvals(A)
#print(A,new_eigvals)
for i in range(len(new_eigvals)):
    print(calc_eigvals[i],new_eigvals[i])
    pass
#print(A, la.eigvals(A))
#print(b)
# Out:
# (2.9992185376+0j) (400.006249982+0j)
# (6.99609398544+0j) (1447.22433696+0j)
# (10.990657021+0j) (257.756040158+0j)
# (14.9881057918+0j) (1373.90871737+0j)
# (95.675517618+0j) (237.063634321+0j)
# (19.04356379+0j) (1366.67724206+0j)
# (23.3767018858+0j) (234.73886162+0j)
# (28.3098076362+0j) (1365.94773042+0j)
# (34.0185870824+0j) (234.552841354+0j)
# (40.5317410214+0j) (1365.94901469+0j)
# (47.8356303939+0j) (234.623269188+0j)
# (84.6423990122+0j) (1366.04915991+0j)
# (74.3293794193+0j) (234.739982212+0j)
# (64.7487289762+0j) (1366.178066+0j)
# (107.416398448+0j) (234.879615882+0j)
# (119.852427065+0j) (1366.32794564+0j)
# (132.970585109+0j) (235.039573921+0j)
# (191.9865628+0j) (1366.4979336+0j)
# (176.280214084+0j) (235.219567844+0j)
# (208.302125914+0j) (1366.68793376+0j)
# (225.210647105+0j) (235.419565598+0j)
# (242.6953151+0j) (1366.89793542+0j)
# (260.738773357+0j) (235.63956362+0j)
# (161.198774505+0j) (1367.12793742+0j)
